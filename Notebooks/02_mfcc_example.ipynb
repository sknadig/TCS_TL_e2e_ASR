# %%
from python_speech_features import mfcc
from scipy.io import wavfile as wav
import matplotlib.pyplot as plt

# %%
(sampling_freq, signal) = wav.read("KerasDeepSpeech/data/ldc93s1/LDC93S1.wav")

# %%
len(signal)
# Out:
# 46797

# %%
plt.plot(signal)

# %%
mfcc_features13 = mfcc(signal=signal, samplerate=sampling_freq)

# %%
type(mfcc_features13)
# Out:
# numpy.ndarray

# %%
mfcc_features13.shape
# Out:
# (291, 13)

# %%
plt.figure(figsize=(10,5))
plt.imshow(mfcc_features13.T, cmap='gray')

# %%
plt.plot(mfcc_features13.T[0])

# %%
mfcc_features26 = mfcc(signal=signal, samplerate=sampling_freq, numcep=26)

# %%
mfcc_features26.shape
# Out:
# (291, 26)
